# %% [markdown]
# # Project - 7
# # ( Udemy_courses.csv )

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('udemy_courses (1).csv')

# %%
data
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %% [markdown]
# # 1. Check for duplicates and drop them

# %%
data = data.drop_duplicates()       # remove duplicate

# %%
data.duplicated().any()              # check duplicate
# Out:
# False

# %% [markdown]
# # 2. Find number of courses per subject

# %%
data.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance
# 1  2017-03-09T16:34:20Z  Business Finance

# %%
data['subject'].value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %% [markdown]
# ### visualize

# %%
plt.xlabel('Courses',color = 'g')
plt.ylabel('Number of courses per subject',color = 'g')
plt.title('Find Number of courses per sub', size = 20,color = 'r')
plt.xticks(rotation = 75)

sns.countplot(data['subject'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 3.  For Which Levels, Udemy Courses Providing The Courses

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %% [markdown]
# ### visualize

# %%
plt.xlabel('level',color = 'g')
plt.ylabel('Number of courses per lavel',color = 'g')
plt.title('Find Number of courses per lavel', size = 20,color = 'r')
plt.xticks(rotation = 75)

sns.countplot(data['level'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 4. Display The Count of Paid and Free Courses

# %%
data.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance
# 1  2017-03-09T16:34:20Z  Business Finance

# %%
data['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
print('Number of paid courses :' ,data['is_paid'].value_counts()[1])
print('Number of free courses :' ,data['is_paid'].value_counts()[0])
# Out:
# Number of paid courses : 3362
# Number of free courses : 310

# %% [markdown]
# ### visualize

# %%
plt.title('Find Number of courses per is_paid', size = 20,color = 'r')
plt.xlabel('is_paid',color = 'g')


plt.xticks(rotation = 75)

sns.countplot(data['is_paid'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 5.Which Course Has More Lectures (Free or Paid)?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance
# 1  2017-03-09T16:34:20Z  Business Finance

# %%
data.groupby(['is_paid']).mean()
# Out:
#              course_id      price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False    691446.970968   0.000000     11533.951613   425.929032     21.416129
# True     674463.946163  72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %% [markdown]
# ### visualize

# %%
plt.title('Lecture per free and paid courses', size = 20,color = 'r')
sns.barplot(x='is_paid', y= 'num_lectures' , data = data)
plt.show()

# %% [markdown]
# # 6.  Which Courses Have A Higher Number of Subscribers Free or Paid?

# %%
data.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance
# 1  2017-03-09T16:34:20Z  Business Finance

# %% [markdown]
# ### visualize

# %%
plt.title('Subscribers per free and paid courses', size = 20,color = 'r')
sns.barplot(x='is_paid', y= 'num_subscribers' , data = data)
plt.show()

# %% [markdown]
# # 7. Which Level Has The Highest Number of Subscribers?

# %%
plt.title('Subscribers per level', size = 20,color = 'r')
plt.xticks(rotation = 75)
sns.barplot(x='level', y= 'num_subscribers' , data = data)
plt.show()

# %% [markdown]
# # 8. Find Most Popular Course Title

# %%
data.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance
# 1  2017-03-09T16:34:20Z  Business Finance

# %%
data[data['num_subscribers'].max() == data['num_subscribers']]['course_title']
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# # 9. Display 10 Most Popular Courses As Per Number of Subscribers

# %%
data.sort_values(by = 'num_subscribers' , ascending = False)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1234     185526                             MicroStation - Células
# 886     1087466  Stop Creditors from Harassing you and Avoid Ba...
# 887     1058852            Learn to trade using technical analysis
# 888     1083744  How to Invest Using ETFs from Former Wall Stre...
# 777     1215926                Kickstarter success in 5 easy steps
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# ...

# %%
data.sort_values(by = 'num_subscribers' , ascending = False).head(10)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %% [markdown]
# ### visualize

# %%
top_10 = data.sort_values(by = 'num_subscribers' , ascending = False).head(10)

# %%
sns.barplot(x='num_subscribers', y= 'course_title' , data = top_10)
# Out:
# <AxesSubplot:xlabel='num_subscribers', ylabel='course_title'>

# %% [markdown]
# # 10. Find The Course Which Is Having The Highest Number of Reviews.

# %%
data.sort_values(by = 'num_reviews' , ascending = False).head(10)['course_title']
# Out:
# 3230                           The Web Developer Bootcamp
# 3232                The Complete Web Developer Course 2.0
# 3204    Angular 4 (formerly Angular 2) - The Complete ...
# 3247            JavaScript: Understanding the Weird Parts
# 3254                              Modern React with Redux
# 3246                       Learn and Understand AngularJS
# 3251                          Learn and Understand NodeJS
# 2827                 Learn HTML5 Programming From Scratch
# 3228    Angular 2 with TypeScript for Beginners: The P...
# 1979    Pianoforall - Incredible New Way To Learn Pian...
# Name: course_title, dtype: object

# %% [markdown]
# ### visualize

# %%
sns.barplot(x='subject', y= 'num_reviews' , data = data)
# Out:
# <AxesSubplot:xlabel='subject', ylabel='num_reviews'>

# %% [markdown]
# # 11.  Does Price Affect the Number of Reviews?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
plt.xticks(rotation = 90)
sns.barplot(x='price', y= 'num_reviews' , data = data)
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_reviews'>

# %%
sns.scatterplot(x='price', y= 'num_reviews' , data = data)
# Out:
# <AxesSubplot:xlabel='price', ylabel='num_reviews'>

# %% [markdown]
# # 12. Find Total Number of Courses Related To Python

# %%
len(data[data['course_title'].str.contains('Python',case = False)])
# Out:
# 29

# %% [markdown]
# # 13. Display 10 Most Popular Python Courses As Per Number of Subscribers

# %%
data[data['course_title'].str.contains('Python',case = False)].sort_values(by = 'num_subscribers' , ascending = False).head(10)
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %% [markdown]
# ### visualize

# %%
python = data[data['course_title'].str.contains('Python',case = False)].sort_values(by = 'num_subscribers' , ascending = False).head(10)

# %%
sns.barplot(x='num_reviews', y= 'course_title' , data = python)
# Out:
# <AxesSubplot:xlabel='num_reviews', ylabel='course_title'>

# %% [markdown]
# # 14. In Which Year The Highest Number of Courses Were Posted?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject', 'year'],
#       dtype='object')

# %% [markdown]
# # 15. Display Category-Wise Count of Posted Subjects [Year Wise]
